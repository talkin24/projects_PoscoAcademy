# %% [markdown]
# #

# %%
# 데이터 구성 패키지: Series, DataFrame
import pandas as pd

# 행렬 연산 패키지
import numpy as np

# 데이터 시각화 패키지
import matplotlib
import matplotlib.pyplot as plt

# 데이터 시각화(추세 등) 패키지
import seaborn as sns

# 추검정 및 통계 분석 패키지
from scipy import stats
import scipy.stats
import statsmodels.api as sm
from statsmodels.stats.proportion import proportions_ztest

# jupyter notebook 내 그래프를 바로 그리기 위한 설정
# %matplotlib inline

# %%
# 한글 폰트(맑은 고딕) 적용
matplotlib.rc('font', family='Malgun Gothic')

# %% [markdown]
# 1. 연습(기술통계) : 자동차 여비 DataSet에서 기술통계치 구하기
#  - 시내에서 연비(mpg) 통계치 : 데이터 수, 평균, 중앙값, 표준편차, min, max, Q1, Q3
#  - 자동차 모델별, mpg 통계치 : 데이터 수, 평균, 중앙값, 표준편차, min, max, Q1, Q3
#  (data set: mycars.csv)

# %%
# seed 선택을 하여 매번 실행 시 동일한 값이 나오도록 설정
np.random.seed(seed = 1234)

# 평균: 20, 표준편차: 2, 데이터 수: 100,000의 정규분포를 따르는 데이터 생성
normal = np.random.normal(20, 2, 100000)

#histogram
sns.distplot(normal)

# %%
# seed 선택을 하여 매번 실행 시 동일한 값이 나오도록 설정
np.random.seed(seed = 1234)

# 평균: 20, 표준편차: 2, 데이터 수: 100,000의 정규분포를 따르는 데이터 생성
normal = np.random.normal(20, 10, 100000)

#histogram
sns.distplot(normal)

# %% [markdown]
#  - 표준편차에 의해서 펑퍼짐해진다.

# %% [markdown]
# ## p.44 [연습] 정규분포 확률계산

# %%
# 누적확률 값 계산
mu = 115
sigma = 20 
x = 135
prob = stats.norm.cdf(x, mu, sigma)
print("{0}분 이상 걸리는 A/S 작업 비율: {1:.1f}%".format(x,(1-prob)*100))
# Out:
# 135분 이상 걸리는 A/S 작업 비율: 15.9%

# %% [markdown]
# ## p.45 [실습] 정규분포 확률계산

# %%
# 누적확률 값 계산
mu = 175
sigma = 5
x = 180
prob = stats.norm.cdf(x, mu, sigma)
print("{0}의 키는 {1:.1f}%".format(x,(1-prob)*100))
# Out:
# 180의 키는 15.9%

# %% [markdown]
# ## p.46 [연습] 정규분포 확률계산

# %%
# 누적확률 값 계산
mu = 12
sigma = 3
x1 = 15
# prob1: 누적확률 15이하 값 계산
prob1 = stats.norm.cdf(x1, mu, sigma)
print("{0}km 이상 {1}km 이하를 달릴 확률은 {2:.1f}% 에 해당함".format(mu, x1,(prob1-0.5)*100))
# Out:
# 12km 이상 15km 이하를 달릴 확률은 34.1% 에 해당함

# %% [markdown]
# ## p.53 [연습] 표준정규분포 그리기

# %%
# seed 선택을 하여 매번 실행 시 동일한 값이 나오도록 설정
np.random.seed(1234)
# 평균: 0, 표준편차: 1, 데이터 수: 100,000의 정규분포를 따르는 데이터 생성
normal = np.random.normal(0, 1, 1000000)
# histogram
sns.distplot(normal)

# 데이터 확인, 소수점 3
normal.round(3)
# Out:
# array([ 0.471, -1.191,  1.433, ...,  1.03 , -1.461,  0.645])

# %% [markdown]
# ## p.57 [연습] t분포 그리기 연습
#  - Random Data 생성 : n = 1,000, degree of freedom = 29
#  - Random Data 생성 : n = 1,000, degree of freedom = 10

# %%
# seed 선택을 하여 매번 실행 시 동일한 값이 나오도록 설정
np.random.seed(1234)
# 자유도: 29, 데이터 수: 1000개의 t 분포를 따르는 데이터 생성
t_df29 = np.random.standard_t(df=29, size = 1000)
# histogram, fit : 정규분포 선 생성, kde: t분포의 kde 생성 안함
sns.distplot(t_df29, fit = stats.norm, kde = False)

# %%
# seed 선택을 하여 매번 실행 시 동일한 값이 나오도록 설정
np.random.seed(1234)
# 자유도: 29, 데이터 수: 1000개의 t 분포를 따르는 데이터 생성
t_df10 = np.random.standard_t(df=10, size = 1000)
# histogram, fit : 정규분포 선 생성, kde: t분포의 kde 생성 안함
sns.distplot(t_df10, fit = stats.norm, kde = False)

# %% [markdown]
# ## p.58 [실습] t분포 그리기 연습(자유도 변화에 따른 분포 변화 이해하기)

# %% [markdown]
# ## P.59 [연습] t 분포
#  - 확률변수 t는 자유도가 5인 t-분포를 따른다.
#  - t값이 1.53일때, P(T<=t)을 계산하시오

# %%
t = 1.53
df = 5
# 누적확률 값 계산
prob = stats.t.cdf(t,df)
print("P(T<=F):{:.3f}".format(prob))
# Out:
# P(T<=F):0.907

# %% [markdown]
# ## p.60 [실습] t분포
# - 확률변수 t는 자유도가 100 인 t-분포를 따른다.
# - t 값이 2.0일 때, P(T<=t)을 계산하시오.

# %%
t = 2.0
df = 100
# 누적확률 값 계산
prob = stats.t.cdf(t,df)
print("P(T<=F):{:.3f}".format(prob))
# Out:
# P(T<=F):0.976

# %% [markdown]
# ## p.62 [연습] 카이제곱 분포
#  - X^2 분포 그리기 연습
#  - Random Data 생성 : n=1000, degree of freedom = 10
#  - Random Data 생성 : n=1000, degree of freedom = 40

# %%
# seed 선택을 하여 매번 실행시 동일한 값이 나오도록 설정
np.random.seed(seed = 1234)

# 자유도: 10, 데이터 수: 1000개의 X^2 분포를 따르는 데이터 생성
chisq_df10 = np.random.chisquare(df=100, size=1000)

# histogram, fit: 정규분포 선 생성, kde: X^2 분포의 kde 생성 안함
sns.distplot(chisq_df10, fit = stats.norm, kde = False)

# %% [markdown]
# ## p.65 [연습] 카이제곱 분포
#  - 확률변수 카이제곱은 자유도가 30인 카이제곱 분포를 따른다
#  - 카이제곱값이 10일때 p(X<= X^2)을 계산하시오.

# %%
chisq = 10
df = 30
# 누적확률 값 계산
prob = stats.chi2.cdf(chisq, df)
print("P(X<={0}) : {1:.4f}".format(chisq, prob))
# Out:
# P(X<=10) : 0.0002

# %% [markdown]
# ## p.69[연습] F-분포

# %%
# seed 선택을 하여 매번 실행 시 동일한 값이 나오도록 설정
np.random.seed(seed = 1234)

# 분자 자유도 10, 분모 자유도: 10
# 데이터 수: 1000개의 F 분포를 따르는 데이터 생성
F_df10_10 = np.random.f(dfnum=10, dfden=10, size=1000)

# histogram, fit: 정규분포 선 생성, kde: F 분포의 kde 생성 안함
sns.distplot(F_df10_10, fit = stats.norm, kde = False)

# %%
# seed 선택을 하여 매번 실행 시 동일한 값이 나오도록 설정
np.random.seed(seed = 1234)

# 분자 자유도 10, 분모 자유도: 10
# 데이터 수: 1000개의 F 분포를 따르는 데이터 생성
F_df10_10 = np.random.f(dfnum=100, dfden=100, size=1000)

# histogram, fit: 정규분포 선 생성, kde: F 분포의 kde 생성 안함
sns.distplot(F_df10_10, fit = stats.norm, kde = False)

# %%
f =2.0
dfnum = 15
dfden = 15

# 누적확률 값 계산
prob = stats.f.cdf(x=f, dfn=dfnum, dfd = dfden)
print("P(X<=F): {:.3f}".format(prob))
# Out:
# P(X<=F): 0.904

# %%
f =1.5
dfnum = 10
dfden = 100

# 누적확률 값 계산
prob = stats.f.cdf(x=f, dfn=dfnum, dfd = dfden)
print("P(X<=F): {:.3f}".format(prob))
# Out:
# P(X<=F): 0.850

# %% [markdown]
# ## weibull 분포
#
#  - 어떤 제품의 수명시간 x가 형상모수 2.2, 척도모수 1,200 인 와이블 분포를 따른다고 할 때, 이 제품이 적어도 1,500시간 이상 작동할 확률을 구하라.

# %%
x = 1500
alpha = 2.2
beta = 1200
# 누적확률 값 계산
prob = stats.weibull_min.cdf(x, alpha, scale = beta)
print("P(X<=x): {:.3f}".format(1 - prob))
# Out:
# P(X<=x): 0.195

# %% [markdown]
# ## 이항분포
#  - 도장공정 광택도 불량 : 40%
#  - 3대의 차량을 임의로 선택했을 때 불량대수가 각각 0, 1, 2, 3 대가나올 확률은?

# %%
# n의 수
n = 3
for i in range(n+1):
    # 이항분포 Probability Mass Function
    prob = stats.binom.pmf(k=i, n=n, p=0.4)
    print("P(X={0}) = {1:.3f}".format(i,prob))
# Out:
# P(X=0) = 0.216
# P(X=1) = 0.432
# P(X=2) = 0.288
# P(X=3) = 0.064

# %% [markdown]
# ## 포아송분포
#
#  - 어느 전화교환대에는 1분당 평균 2회의 전화가 걸려 온다고 한다.
#  - 전화의 도착 횟수가 포아송분포를 따른다면,
#   - 이 교환대에 1분당 3번의 전화가 걸려올 확률은?
#   - 이 교환대에 1분당 최대 2회 이하의 전화가 걸려올 확률은?

# %%
# 평균
mu = 2
# 1분당 3번의 전화가 걸려올 확률
prob = stats.poisson.pmf(3, mu)
# 1분당 최대 2회 이하의 전화가 걸려올 확률
cdf_prob = stats.poisson.cdf(2, mu)
print("1분당 {0}번의 전화가 걸려올 확률: {1:.1f}%".format(3, prob*100))
print("1분당 최대{0}회 이하의 전화가 걸려올 확률: {1:.1f}%".format(2, cdf_prob*100))
# Out:
# 1분당 3번의 전화가 걸려올 확률: 18.0%
# 1분당 최대2회 이하의 전화가 걸려올 확률: 67.7%
